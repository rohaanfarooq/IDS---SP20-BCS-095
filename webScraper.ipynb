# %%
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get('https://www.forbes.com/big-data/?sh=2a52dfa516d1')

# %%
response.status_code
# Out:
# 200

# %%
response.url
# Out:
# 'https://www.forbes.com/big-data/?sh=2a52dfa516d1'

# %%
response.text
# Out:
# '<!DOCTYPE html><html lang="en"><head><link rel="preload" as="font" href="https://i.forbesimg.com/assets/fonts/merriweather/merriweather-bold-webfont.woff2" type="font/woff2" crossorigin><link rel="preload" as="font" href="https://i.forbesimg.com/assets/fonts/merriweather/merriweather-regular-webfont.woff2" type="font/woff2" crossorigin><link rel="preload" as="font" href="https://i.forbesimg.com/assets/fonts/work-sans/worksans-regular-webfont.woff2" type="font/woff2" crossorigin><link rel="preload" as="font" href="https://i.forbesimg.com/assets/fonts/EuclidCircular/EuclidCircularB-Regular.otf" type="font/otf" crossorigin><meta charset="UTF-8"><meta http-equiv="Content-Language" content="en_US"><meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=5,minimum-scale=1,user-scalable=yes"><title itemprop="headline">Big Data</title><link rel="shortcut icon" href="https://i.forbesimg.com/48X48-F.png"><link rel="canonical" href="https://www.forbes.com/big-data/"><lin
# ...

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
data = soup.find_all('a', attrs={'class':'stream-item__title'})

# %%
data
# Out:
# [<a class="stream-item__title" data-ga-track="Innovation - Stream - Position 1 - IEEE 2883 Standard On Data Sanitization Is A Path To Storage Reuse And Recycling" href="https://www.forbes.com/sites/tomcoughlin/2022/09/23/ieee-2883-standard-on-data-sanitization-is-a-path-to-storage-reuse-and-recycling/">IEEE 2883 Standard On Data Sanitization Is A Path To Storage Reuse And Recycling</a>,
#  <a class="stream-item__title" data-ga-track="Innovation - Stream - Position 2 - Crypto Darling Helium Promised A ‘People’s Network.’ Instead, Its Executives Got Rich." href="https://www.forbes.com/sites/sarahemerson/2022/09/23/helium-crypto-tokens-peoples-network/">Crypto Darling Helium Promised A ‘People’s Network.’ Instead, Its Executives Got Rich.</a>,
# ...

# %%
for x in data:
    print(x.text)
# Out:
# IEEE 2883 Standard On Data Sanitization Is A Path To Storage Reuse And Recycling
# Crypto Darling Helium Promised A ‘People’s Network.’ Instead, Its Executives Got Rich.
# Why Modern Business Runs On Data Streaming
# CXL Ecosystem Enabling Memory Fabrics
# Moneyball 20 Years Later: A Progress Report On Data And Analytics In Professional Sports
# We Need A Boost In HDD Areal Density!
# IBM Research’s Path To Serverless Quantum Computing
# Big Storage For Archiving Data
# Steering The IT Convoy Around Data Pitfalls, Perils And Potholes
# Startup Behind AI Image Generator Stable Diffusion Is In Talks To Raise At A Valuation Up To $1 Billion
# This 17-Year Old Created An AI-Powered App To Help Farmers Across The World
# AI Ethics: Why You Should Care
# Data As A Product, Redefining Our Approach To Producing Value From Data
# A Citizen Test, Users Move Closer To Software Development
# 8 Pitfalls In The Data-Driven Decision-Making (DDDM) Process
# Emerging Memory To Grow To $44B By 2032
# ...
